# %% [markdown]
# <a href="https://colab.research.google.com/github/byui-cse/cse380-notebooks/blob/master/12_3_About_Deterministic_Finite_Automata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About Deterministic Finite Automata
# ## Class Directed Learning
# ### Due: Tuesday, 23 March 2021, 11:59 pm

# %% [markdown]
# Any study of Deterministic Finite Automata (DFA) would be incomplete without looking into "Language Recognition" --- an area of discrete math that leads us into territory abounding in rich structures and powerful ideas.
#
# The notion of a finite-state machine **with** output generalizes to the notion of a finite-state machine (aka a finite automaton) with **no** output, but with important computational abilities.
#
# For now, we focus on **deterministic** computations.

# %% [markdown]
# For all of the following examples and tasks, the alphabet is $\Sigma = \{0, 1\}$, and the idea is to construct a DFA serving as a language recognizer for the given languages.

# %% [markdown]
# ## Example 1

# %% [markdown]
# The language
#
# $L_0 = \{x0\ |\ x \in \Sigma^*\}$
#
# needs two states in order to:
#
# 1. Accept strings that end in 0.
# 2. Reject strings that end in 1.

# %%
from graphviz import Source

# %%
last_bit_is_zero = '''
digraph {
  node [shape=circle]
  empty [shape=none label=""]
  S0 [shape=doublecircle]
  S1
  empty -> S1 [label="" headport=w]
  S1 -> S1 [label=1 headport=ne tailport=nw]
  S1 -> S0 [label=0]
  S0 -> S0 [label=0 headport=ne tailport=nw]
  S0 -> S1 [label=1]
  {rank=same empty S1 S0}
}
'''
Source(last_bit_is_zero)

# %% [markdown]
# ## Example 2

# %% [markdown]
# The language
#
# $L_1 = \{x0z\ |\ x \in \Sigma^*, z \in \Sigma\}$
#
# needs four states in order to:
#
# 1. Accept strings that end in 00 or 01.
# 2. Reject strings that end in 10 or 11.

# %%
second_to_last_bit_is_zero = '''
digraph {
  node [shape=circle]
  empty [shape=none label=""]
  S11
  S10
  S00 [shape=doublecircle]
  S01 [shape=doublecircle]

  empty -> S11 [label="" headport=w]
  S11 -> S10 [label=0]
  S11 -> S11 [label=1 headport=ne tailport=nw]
  S10 -> S00 [label=0]
  S10 -> S01 [label=1]
  S00 -> S00 [label=0 tailport=w]
  S00 -> S01 [label=1]
  S01 -> S10 [label=0]
  S01 -> S11 [label=1]
  {rank=same empty S11 S10}
  {rank=same S01 S00}
}
'''
Source(second_to_last_bit_is_zero)

# %% [markdown]
# ## TODO Task 1

# %% [markdown]
# Construct a DFA to recognize the language
#
# $L_2 = \{x0z\ |\ x \in \Sigma^*, z \in \Sigma^2\}$.

# %%
third_to_last_bit_is_zero = '''
digraph {
  node [shape=circle]
  empty [shape=none label=""]
  S111
  S110
  S100
  S101
  S000 [shape=doublecircle]
  S010 [shape=doublecircle]
  S001 [shape=doublecircle]
  S011 [shape=doublecircle]

  empty -> S111 [label="" headport=w]
  S111 -> S110 [label=0]
  S111 -> S111 [label=1 headport=ne tailport=nw]
  S110 -> S101 [label=1]
  S110 -> S100 [label=0]
  S100 -> S000 [label=0]
  S100 -> S001 [label=1]
  S001 -> S010 [label=0]
  S001 -> S011 [label=1]
  S011 -> S110 [label=0]
  S011 -> S111 [label=1]
  S000 -> S001 [label=1]
  S000 -> S000 [label=0 tailport=w]
  S010 -> S101 [label=1]
  S010 -> S100 [label=0]
  S101 -> S011 [label=1]
  S101 -> S010 [label=0]
  {rank=same empty S111 S100 S101 S110}
  {rank=same S010 S000 S011 S001}
}
'''
Source(second_to_last_bit_is_zero)

# %% [markdown]
# ## TODO Task 2

# %% [markdown]
# Construct a DFA to recognize the language
#
# $L_3 = \{x0z\ |\ x \in \Sigma^*, z \in \Sigma^3\}$.

# %%
fourth_to_last_bit_is_zero = '''
digraph {
  node [shape=circle]
  empty [shape=none label=""]
  S1111
  S1110
  S1100
  S1101
  S1000 
  S1010 
  S1001 
  S1011 
  S0111 [shape=doublecircle]
  S0110 [shape=doublecircle]
  S0100 [shape=doublecircle]
  S0101 [shape=doublecircle]
  S0000 [shape=doublecircle]
  S0010 [shape=doublecircle]
  S0001 [shape=doublecircle]
  S0011 [shape=doublecircle]

  empty -> S1111 [label="" headport=w]
  S1111 -> S1110 [label=0]
  S1111 -> S1111 [label=1 headport=ne tailport=nw]
  S1110 -> S1101 [label=1]
  S1110 -> S1100 [label=0]
  S1100 -> S1000 [label=0]
  S1100 -> S1001 [label=1]
  S1001 -> S1010 [label=0]
  S1001 -> S0011 [label=1]
  S1011 -> S0110 [label=0]
  S1011 -> S0111 [label=1]
  S1000 -> S0001 [label=1]
  S1000 -> S0000 [label=0]
  S1010 -> S0101 [label=1]
  S1010 -> S0100 [label=0]
  S1101 -> S1011 [label=1]
  S1101 -> S1010 [label=0]
  S0111 -> S1110 [label=0]
  S0111 -> S1111 [label=1]
  S0110 -> S1101 [label=1]
  S0110 -> S1100 [label=0]
  S0100 -> S1000 [label=0]
  S0100 -> S1001 [label=1]
  S0001 -> S0010 [label=0]
  S0001 -> S0011 [label=1]
  S0011 -> S0110 [label=0]
  S0011 -> S0111 [label=1]
  S0000 -> S0001 [label=1]
  S0000 -> S0000 [label=0 tailport=w]
  S0010 -> S0101 [label=1]
  S0010 -> S0100 [label=0]
  S0101 -> S1011 [label=1]
  S0101 -> S1010 [label=0]
  {rank=same empty S1111 S1100 S1101 S1110 S1010 S1000 S1011 S1001}
  {rank=same S0111 S0100 S0101 S0110 S0010 S0000 S0011 S0001}
}
'''
Source(fourth_to_last_bit_is_zero)

# %% [markdown]
# ## TODO Task 3

# %% [markdown]
# Construct a DFA to recognize the language
#
# $L_4 = \{x0z\ |\ x \in \Sigma^*, z \in \Sigma^4\}$.

# %%
fifth_to_last_bit_is_zero = '''
digraph {
  node [shape=circle]
  empty [shape=none label=""]
  S11111
  S11110
  S11100
  S11101
  S11000 
  S11010 
  S11001 
  S11011 
  S10111 
  S10110 
  S10100 
  S10101 
  S10000 
  S10010 
  S10001 
  S10011
  S01111 [shape=doublecircle]
  S01110 [shape=doublecircle]
  S01100 [shape=doublecircle]
  S01101 [shape=doublecircle]
  S01000 [shape=doublecircle]
  S01010 [shape=doublecircle]
  S01001 [shape=doublecircle]
  S01011 [shape=doublecircle]
  S00111 [shape=doublecircle]
  S00110 [shape=doublecircle]
  S00100 [shape=doublecircle]
  S00101 [shape=doublecircle]
  S00000 [shape=doublecircle]
  S00010 [shape=doublecircle]
  S00001 [shape=doublecircle]
  S00011 [shape=doublecircle]

  empty -> S11111 [label="" headport=w]
  S11111 -> S11110 [label=0]
  S11111 -> S11111 [label=1 headport=ne tailport=nw]
  S11110 -> S11101 [label=1]
  S11110 -> S11100 [label=0]
  S11100 -> S11000 [label=0]
  S11100 -> S11001 [label=1]
  S11001 -> S11010 [label=0]
  S11001 -> S10011 [label=1]
  S11011 -> S10110 [label=0]
  S11011 -> S10111 [label=1]
  S11000 -> S10001 [label=1]
  S11000 -> S10000 [label=0]
  S11010 -> S10101 [label=1]
  S11010 -> S10100 [label=0]
  S11101 -> S11011 [label=1]
  S11101 -> S11010 [label=0]
  S10111 -> S01110 [label=0]
  S10111 -> S01111 [label=1]
  S10110 -> S01101 [label=1]
  S10110 -> S01100 [label=0]
  S10100 -> S01000 [label=0]
  S10100 -> S01001 [label=1]
  S10001 -> S00010 [label=0]
  S10001 -> S00011 [label=1]
  S10011 -> S00110 [label=0]
  S10011 -> S00111 [label=1]
  S10000 -> S00001 [label=1]
  S10000 -> S00000 [label=0 tailport=w]
  S10010 -> S00101 [label=1]
  S10010 -> S00100 [label=0]
  S10101 -> S01011 [label=1]
  S10101 -> S01010 [label=0]
  S01111 -> S11110 [label=0]
  S01111 -> S11111 [label=1 headport=ne tailport=nw]
  S01110 -> S11101 [label=1]
  S01110 -> S11100 [label=0]
  S01100 -> S11000 [label=0]
  S01100 -> S11001 [label=1]
  S01001 -> S11010 [label=0]
  S01001 -> S10011 [label=1]
  S01011 -> S10110 [label=0]
  S01011 -> S10111 [label=1]
  S01000 -> S10001 [label=1]
  S01000 -> S10000 [label=0]
  S01010 -> S10101 [label=1]
  S01010 -> S10100 [label=0]
  S01101 -> S11011 [label=1]
  S01101 -> S11010 [label=0]
  S00111 -> S01110 [label=0]
  S00111 -> S01111 [label=1]
  S00110 -> S01101 [label=1]
  S00110 -> S01100 [label=0]
  S00100 -> S01000 [label=0]
  S00100 -> S01001 [label=1]
  S00001 -> S00010 [label=0]
  S00001 -> S00011 [label=1]
  S00011 -> S00110 [label=0]
  S00011 -> S00111 [label=1]
  S00000 -> S00001 [label=1]
  S00000 -> S00000 [label=0 tailport=w]
  S00010 -> S00101 [label=1]
  S00010 -> S00100 [label=0]
  S00101 -> S01011 [label=1]
  S00101 -> S01010 [label=0]
  {rank=same empty S11111 S11100 S11101 S11110 S11010 S11000 S11011 S11001 S10111 S10100 S10101 S10110 S10010 S10000 S10011 S10001}
  {rank=same S01111 S01100 S01101 S01110 S01010 S01000 S01011 S01001 S00111 S00100 S00101 S00110 S00010 S00000 S00011 S00001}
}
'''
Source(fifth_to_last_bit_is_zero)
